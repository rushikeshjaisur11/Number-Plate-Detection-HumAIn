# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !pip install patool
import os 
print(os.getcwd())
# Out:
# Requirement already satisfied: patool in /usr/local/lib/python3.6/dist-packages (1.12)
# /content

# %%
import patoolib
patoolib.extract_archive("/content/drive/My Drive/OCR_Dataset/Dataset.rar", outdir="/content")
# Out:
# patool: Extracting /content/drive/My Drive/OCR_Dataset/Dataset.rar ...
# patool: running /usr/bin/unrar x -- "/content/drive/My Drive/OCR_Dataset/Dataset.rar"
# patool:     with cwd='/content'
# ---------------------------------------------------------------------------
# PatoolError                               Traceback (most recent call last)
# <ipython-input-4-14681e48b555> in <module>()
#       1 import patoolib
# ----> 2 patoolib.extract_archive("/content/drive/My Drive/OCR_Dataset/Dataset.rar", outdir="/content")
#
# /usr/local/lib/python3.6/dist-packages/patoolib/__init__.py in extract_archive(archive, verbosity, outdir, program, interactive)
#     682     if verbosity >= 0:
#     683         util.log_info("Extracting %s ..." % archive)
# --> 684     return _extract_archive(archive, verbosity=verbosity, interactive=interactive, outdir=outdir, program=program)
#     685
#     686
#
# /usr/local/lib/python3.6/dist-packages/patoolib/__init__.py in _extract_archive(archive, verbosity, interactive, outdir, program, format, compression)
#     482             # already handled the command (eg. when it's a builtin Python
#     483             # function)
# --> 484             run_archive_cmdlist(cmdlist, verbosity=verbosity)
#     485         if do_cleanup_outdir:
#     486             target, msg = cleanup_outdir(outdir, archive)
#
# /usr/local/lib/python3.6/dist-packages/patoolib/__init__.py in run_archive_cmdlist(archive_cmdlist, verbosity)
#     419     else:
#     420         cmdlist, runkwargs = archive_cmdlist, {}
# --> 421     return util.run_checked(cmdlist, verbosity=verbosity, **runkwargs)
#     422
#     423
#
# /usr/local/lib/python3.6/dist-packages/patoolib/util.py in run_checked(cmd, ret_ok, **kwargs)
#     225     if retcode not in ret_ok:
#     226         msg = "Command `%s' returned non-zero exit status %d" % (cmd, retcode)
# --> 227         raise PatoolError(msg)
#     228     return retcode
#     229
#
# PatoolError: Command `['/usr/bin/unrar', 'x', '--', '/content/drive/My Drive/OCR_Dataset/Dataset.rar']' returned non-zero exit status 255

# %%
from keras.models import Sequential # To initialise the nn as a sequence of layers
from keras.layers import Convolution2D # To make the convolution layer for 2D images
from keras.layers import MaxPooling2D # 
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import CSVLogger
from keras.optimizers import RMSprop

classifier = Sequential()

classifier.add(Convolution2D(32,(3,3),input_shape = (64,64,3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))

classifier.add(Convolution2D(32,(3,3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2,2)))
classifier.add(Flatten())

classifier.add(Dense(128, activation = 'relu'))
classifier.add(Dropout((0.07)))
classifier.add(Dense(36, activation = 'softmax'))
csv=CSVLogger("epochs2.log")

classifier.compile(optimizer = RMSprop(lr=0.001,rho=0.9,epsilon=1e-08,decay=0.005), loss = 'categorical_crossentropy', metrics = ['accuracy'])

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_set = train_datagen.flow_from_directory('Dataset/Train',target_size=(64, 64),batch_size=32,class_mode='categorical')

test_set = test_datagen.flow_from_directory('Dataset/Test',target_size=(64, 64),batch_size=32,class_mode='categorical')

classifier.fit_generator(train_set,steps_per_epoch=47605,epochs=5,validation_data=test_set,validation_steps=1292,callbacks=[csv])

classifier.save('OCR_MODEL.h5')
# Out:
# Found 99739 images belonging to 36 classes.
# Found 21945 images belonging to 36 classes.
# Epoch 1/5
# 47605/47605 [==============================] - 845s 18ms/step - loss: 0.1850 - acc: 0.9499 - val_loss: 0.5475 - val_acc: 0.8660
# Epoch 2/5
# 47605/47605 [==============================] - 844s 18ms/step - loss: 0.1411 - acc: 0.9617 - val_loss: 0.5475 - val_acc: 0.8676
# Epoch 3/5
# 47605/47605 [==============================] - 836s 18ms/step - loss: 0.1333 - acc: 0.9639 - val_loss: 0.5426 - val_acc: 0.8698
# Epoch 4/5
# 47605/47605 [==============================] - 839s 18ms/step - loss: 0.1285 - acc: 0.9652 - val_loss: 0.5409 - val_acc: 0.8700
# Epoch 5/5
# 47605/47605 [==============================] - 853s 18ms/step - loss: 0.1255 - acc: 0.9661 - val_loss: 0.5480 - val_acc: 0.8699

# %%
from google.colab import drive
drive.mount('/content/drive')
